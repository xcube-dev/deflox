# %%
import pandas as pd

# %%
raw = pd.read_csv("sample-data\\070103.CSV", sep=";")
raw
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
reflectance_full = pd.read_csv("C:\\Users\\Thomas\\work\\DEFLOX\\240309\\Reflectance_FULL_F070003.csv", sep=";")
reflectance_full

# %%
reflectance_fluo = pd.read_csv("C:\\Users\\Thomas\\work\\DEFLOX\\240309\\Reflectance_FLUO_070003.csv", sep=";")
reflectance_fluo

# %%
reflected_radiance = pd.read_csv("C:\\Users\\Thomas\\work\\DEFLOX\\240309\\Reflected_radiance_FULL_F070003.csv", sep=";")
reflected_radiance

# %%
incoming_radiance = pd.read_csv("C:\\Users\\Thomas\\work\\DEFLOX\\240309\\Incoming_radiance_FLUO_070003.csv", sep=";")
incoming_radiance
